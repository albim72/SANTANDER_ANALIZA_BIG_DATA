# %%
a = 78
b = 7.85
c = a+b
print(c)
# Out:
# 85.85

# %%
b = True
c = a-b
print(c)
# Out:
# 77

# %% [markdown]
# # To jest pierwszy notebook

# %% [markdown]
# **Jupyter Notebook** z podstawami <span style="color:red; font-size:16pt;">Datalore</span>

# %%
lsztuk = 9

# %%
pakiet = "12"

# %%
lsztuk*int(pakiet)
# Out:
# 108
